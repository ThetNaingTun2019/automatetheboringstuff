# %%
import pandas as pd
df=pd.read_excel('pandas test.xlsx',sheet_name=1,index_col=0)
df.head()
# Out:
#             Unnamed: 1 Unnamed: 2  \
# <table>
# <thead><td>  Part Nome  </td><td>
# <tr><td>          PIPE  </td><td>
# <tr><td>          PIPE  </td><td>
# <tr><td>          PIPE  </td><td>
# <tr><td>          PIPE  </td><td>
#
#                                                     Unnamed: 3 Unnamed: 4  \
# <table>
# <thead><td>                                    RAW Description  </td><td>
# <tr><td>     1A002BC PIP  PIPE A672-C55(A516-55) CL.12 EFW ...  </td><td>
# <tr><td>     1A002BP PIP  A672-C55(A516-55) CL-12 EFW SCH 1...  </td><td>
# <tr><td>     1A002CC PIP  PIPE A672-C55(A516-55) CL.12 EFW ...  </td><td>
# <tr><td>     1A002CP PIP  A672-C55(A516-55) CL-12 EFW SCH 2...  </td><td>
#
#             Unnamed: 5 Unnamed: 6  \
# <table>
# <thead><td>       MENO  </td><td>
# <tr><td>       1A002BC  </td><td>
# <tr><td>       1A002BP  </td><td>
# <tr><td>       1A002CC  </td><td>
# <tr><td>       1A002CP  </td><td>
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# count      262168     262344      262344     262344     262349     262344
# unique         10          1      262168          1     262348          1
# top       FITTING  </td><td>           1  </td><td>    1A041XS  </td><td>
# freq       136886     262344         176     262344          2     262344
#
#          Unnamed: 7  Unnamed: 8           Unnamed: 9 Unnamed: 10  \
# count        262349      262344                    5           5
# unique       261345           2                    2           2
# top     SPS CNST-TP  </td></tr>  2023-06-13 00:00:00         LR2
# freq             10      262343                    4           4
#
#              Unnamed: 11  Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# count                552         1111         592         391         294
# unique                34           22           2           9          19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 402941 entries, 1A1A to ZSC035
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Part Name            402941 non-null  object
#  1   Short Code           402941 non-null  object
#  2   Size Range           402941 non-null  object
#  3   Size L               9218 non-null    float64
#  4   Size S               4740 non-null    float64
#  5   Ident Code           402941 non-null  object
#  6   Worked_ident code    402941 non-null  object
#  7   Description          402941 non-null  object
#  8   Area                 402941 non-null  object
#  9   Issued YearMonthDay  402941 non-null  int64
#  10  Unique ID            402941 non-null  object
#  11  Count_1              402941 non-null  int64
#  12  Count_2              402941 non-null  int64
#  13  Unique ID per SVC    402941 non-null  object
#  14  Count_3              402941 non-null  int64
# ...

# %%
# importing required modules
from PyPDF2 import PdfReader

# creating a pdf reader object
reader = PdfReader('pdf/S-00-1520-005.pdf')

# printing number of pages in pdf file
print(len(reader.pages))

# getting a specific page from the pdf file
page = reader.pages[0]

# extracting text from page
text = page.extract_text()
print(text)
# Out:
# 5
# I
# Job No. Doc. No. Rev.
# )GC I Kellogg )oint Venture 0-9000 500-1 520-005· 2 • Ras Laffan Onshore Facilities Project Date jun. 28, 96 Sheet 1 oi 5
# Prp'd K.Moriki
# Pressure Containing Equipment - Chk'd T.Saita
# Welding and Weld Inspection App'd Y.Ushio
# CONTENTS
# 1.0 Scope
# 2.0 Reference
# 3.0 Modifications.to Mobil Engineering Guide EGE 00-B-21 -1993 • •
# Note: This document is sourced from S-00-10 Rev. 0 and used for Ras Laffan Onshore Facilities.
# S:ISPEC\SOOI1520005.WPS
# jFor Information \\ \For Review \1 \For Approval jj J:or Construaion ) As Built
# Rev Date Page Description Prpd Chkd Appd
# 0 May 13 '96 All Issued for Company's Approval K.M. T.S. Y.U.
# ., Jun. 26 '96 2 & 3 Issued for Construction (Updated referenced spec. No. etc.J • 2 Feb. 08 '99 All As Built

# %% [markdown]
# https://stackoverflow.com/questions/45480280/convert-scanned-pdf-to-text-python

# %%
import pytesseract
from pdf2image import convert_from_path
import glob

pdfs = glob.glob(r"pdf/S-00-1520-005.pdf")

for pdf_path in pdfs:
    pages = convert_from_path(pdf_path, 500)

    for pageNum,imgBlob in enumerate(pages):
        text = pytesseract.image_to_string(imgBlob,lang='eng')

        with open(f'{pdf_path[:-4]}_page{pageNum}.txt', 'w',encoding='utf-8') as the_file:
            the_file.write(text)

# %% [markdown]
# Installer Package

# %%
import tkinter as tk

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300)
canvas1.pack()

def hello ():  
    label1 = tk.Label(root, text= 'Man Hour, Please!', fg='blue', font=('helvetica', 12, 'bold'))
    canvas1.create_window(150, 200, window=label1)
    
button1 = tk.Button(text='Click Me', command=hello, bg='brown',fg='white')
canvas1.create_window(150, 150, window=button1)

root.mainloop()

# %%
# !pyinstaller --onefile "singlefile_exe.py" --noconsole
# Out:
# 291 INFO: PyInstaller: 6.8.0, contrib hooks: 2024.7
# 291 INFO: Python: 3.11.9
# 302 INFO: Platform: Windows-10-10.0.22631-SP0
# 303 INFO: Python environment: d:\my_python\.venv
# 303 INFO: wrote D:\my_python\singlefile_exe.spec
# 306 INFO: Module search paths (PYTHONPATH):
# ['D:\\my_python\\.venv\\Scripts\\pyinstaller.exe',
#  'C:\\python\\python311.zip',
#  'C:\\python\\DLLs',
#  'C:\\python\\Lib',
#  'C:\\python',
#  'd:\\my_python\\.venv',
#  'd:\\my_python\\.venv\\Lib\\site-packages',
#  'd:\\my_python\\.venv\\Lib\\site-packages\\win32',
#  'd:\\my_python\\.venv\\Lib\\site-packages\\win32\\lib',
#  'd:\\my_python\\.venv\\Lib\\site-packages\\Pythonwin',
#  'D:\\my_python']
# 577 INFO: checking Analysis
# 578 INFO: Building because inputs changed
# 578 INFO: Running Analysis Analysis-00.toc
# 578 INFO: Target bytecode optimization level: 0
# 578 INFO: Initializing module dependency graph...
# 579 INFO: Caching module graph hooks...
# 591 INFO: Analyzing base_library.zip ...
# ...

# %%
# !pyinstaller --onefile "hello.py" --noconsole
# Out:
# 9245 INFO: PyInstaller: 5.10.1
# 9245 INFO: Python: 3.10.8 (conda)
# 9291 INFO: Platform: Windows-10-10.0.19044-SP0
# 9292 INFO: wrote C:\Users\104200002031\OneDrive - Chiyoda Corporation\CAEL2031 Works\GeneralTesting\hello.spec
# 9307 INFO: UPX is not available.
# 9310 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\104200002031\\OneDrive - Chiyoda Corporation\\CAEL2031 '
#  'Works\\GeneralTesting']
# 11623 INFO: checking Analysis
# 11649 INFO: Building because hookspath changed
# 11649 INFO: Initializing module dependency graph...
# 11654 INFO: Caching module graph hooks...
# 11737 INFO: Analyzing base_library.zip ...
# 24819 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\104200002031\\Miniconda3\\envs\\CAEL_DS\\lib\\site-packages\\PyInstaller\\hooks'...
# 25159 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\104200002031\\Miniconda3\\envs\\CAEL_DS\\lib\\site-packages\\PyInstaller\\hooks'...
# ...

# %% [markdown]
# # PyGTK

# %%
import pygtk
pygtk.require('2.0')
import gtk

class HelloWorld:

   # this is a function later used as a callback
   def hello(self, widget, data=None):
       print("Hello World")

   def destroy(self, widget, data=None):
      gtk.main_quit()

   def __init__(self):
      self.window = gtk.Window(gtk.WINDOW_TOPLEVEL)

      self.window.connect("destroy", self.destroy)      
      self.window.set_border_width(10)
      
      self.button = gtk.Button("Hello World")

      # this next line connects the button, the click event and the function
      self.button.connect("clicked", self.hello, None)
      
      # here we add the button to the window 
      self.window.add(self.button)

      # we must also show both the button and the window
      self.button.show()
      self.window.show()

   def main(self):
      gtk.main()

if __name__ == "__main__":
   hello = HelloWorld()
   hello.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 import pygtk
#       2 pygtk.require('2.0')
#       3 import gtk
#
# ModuleNotFoundError: No module named 'pygtk'

# %%
# !pip install pyGTK
# Out:
# ...
#   Using cached pygtk-2.24.0.tar.bz2 (2.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   ERROR: Could not import dsextras module: Make sure you have installed pygobject.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# # PyQT

# %%
import sys
#from PyQt5 import QtGui #Not available in PyQT5
from PyQt5 import QtWidgets

def window():
   app = QtWidgets.QApplication(sys.argv)
   w = QtWidgets.QWidget()
   b = QtWidgets.QLabel(w)
   b.setText("Hello World!")
   w.setGeometry(100,100,200,50)
   b.move(50,20)
   w.setWindowTitle("PyQt")
   w.show()
   sys.exit(app.exec_())
	
if __name__ == '__main__':
   window()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\104200002031\Miniconda3\envs\CAEL_DS\lib\site-packages\IPython\core\interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !pyinstaller --onefile "Piping Tools-PyQt.py" --noconsole
# Out:
# 3118 INFO: PyInstaller: 5.10.1
# 3119 INFO: Python: 3.10.8 (conda)
# 3160 INFO: Platform: Windows-10-10.0.19044-SP0
# 3161 INFO: wrote C:\Users\104200002031\OneDrive - Chiyoda Corporation\CAEL2031 Works\GeneralTesting\Piping Tools-PyQt.spec
# 3164 INFO: UPX is not available.
# 3167 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\104200002031\\OneDrive - Chiyoda Corporation\\CAEL2031 '
#  'Works\\GeneralTesting']
# 4650 INFO: checking Analysis
# 4650 INFO: Building Analysis because Analysis-00.toc is non existent
# 4650 INFO: Initializing module dependency graph...
# 4654 INFO: Caching module graph hooks...
# 4682 INFO: Analyzing base_library.zip ...
# 15204 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\104200002031\\Miniconda3\\envs\\CAEL_DS\\lib\\site-packages\\PyInstaller\\hooks'...
# 15515 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\104200002031\\Miniconda3\\envs\\CAEL_DS\\lib\\site-packages\\PyInstaller\\hooks'...
# ...
